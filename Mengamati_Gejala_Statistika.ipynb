# %% [markdown]
# # **1. Pengaruh Nilai Ekstrim**
#
# Pada bagian ini kalian akan mengamati pengaruh nilai ekstrim terhadap 2 ukuran pemusatan data (mean dan median).
#
# ## 📖 **Soal**
#
# 7 Karyawan DQTech, diketahui mempunyai data gaji sebagai berikut
#
# <br>
#
# <table>
#         <thead>
#             <tr>
#                 <th>No</th>
#                 <th>Nama</th>
#                 <th>Gaji (Rp)</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>1</td>
#                 <td>Andi Pratama</td>
#                 <td>5.800.000</td>
#             </tr>
#             <tr>
#                 <td>2</td>
#                 <td>Budi Santoso</td>
#                 <td>5.500.000</td>
#             </tr>
#             <tr>
#                 <td>3</td>
#                 <td>Citra Dewi</td>
#                 <td>4.700.000</td>
#             </tr>
#             <tr>
#                 <td>4</td>
#                 <td>Dani Fadilah</td>
#                 <td>6.500.000</td>
#             </tr>
#             <tr>
#                 <td>5</td>
#                 <td>Eka Putra</td>
#                 <td>6.000.000</td>
#             </tr>
#             <tr>
#                 <td>6</td>
#                 <td>Fajar Hidayat</td>
#                 <td>4.900.000</td>
#             </tr>
#             <tr>
#                 <td>7</td>
#                 <td>Gita Saraswati</td>
#                 <td>5.200.000</td>
#             </tr>
#         </tbody>
#   </table>
#
# dengan menggunakan list pada Python hitunglah rata-rata gaji karyawan di DQTech!

# %%
data_1 = [5800000, 5500000, 4700000, 6500000, 6000000, 4900000, 5200000]

mean_1 = sum(data_1)/len(data_1)
print(f'{mean_1:.2f}')
# Out:
# 5514285.71

# %% [markdown]
# Kemudian hitung median datanya juga ya!

# %%
data_1 = [5800000, 5500000, 4700000, 6500000, 6000000, 4900000, 5200000]
data_1.sort()

median_1 = data_1[len(data_1)//2]
print(median_1)
# Out:
# 5500000

# %% [markdown]
# Wah, saat ini terdapat karyawan baru bernama Cakra Negara yang memiliki gaji fantastis yakni Rp. 17.000.000, sehingga data gaji karyawan DQTech saat ini menjadi
#
# <br>
#
# <table>
#         <thead>
#             <tr>
#                 <th>No</th>
#                 <th>Nama</th>
#                 <th>Gaji (Rp)</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>1</td>
#                 <td>Andi Pratama</td>
#                 <td>5.800.000</td>
#             </tr>
#             <tr>
#                 <td>2</td>
#                 <td>Budi Santoso</td>
#                 <td>5.500.000</td>
#             </tr>
#             <tr>
#                 <td>3</td>
#                 <td>Citra Dewi</td>
#                 <td>4.700.000</td>
#             </tr>
#             <tr>
#                 <td>4</td>
#                 <td>Dani Fadilah</td>
#                 <td>6.500.000</td>
#             </tr>
#             <tr>
#                 <td>5</td>
#                 <td>Eka Putra</td>
#                 <td>6.000.000</td>
#             </tr>
#             <tr>
#                 <td>6</td>
#                 <td>Fajar Hidayat</td>
#                 <td>4.900.000</td>
#             </tr>
#             <tr>
#                 <td>7</td>
#                 <td>Gita Saraswati</td>
#                 <td>5.200.000</td>
#             </tr>
#             <tr>
#                 <td>8</td>
#                 <td>Cakra Negara</td>
#                 <td>17.000.000</td>
#             </tr>
#         </tbody>
#   </table>
#
# Hitung kembali rata-rata gaji karyawan di DQTech saat ini!

# %%
data_2 = [5800000, 5500000, 4700000, 6500000, 6000000, 4900000, 5200000, 17000000]

mean_2 = sum(data_2)/len(data_2)
print(f'{mean_2:.2f}')
# Out:
# 6950000.00

# %% [markdown]
# Kemudian hitung median data barunya juga ya!

# %%
data_2 = [5800000, 5500000, 4700000, 6500000, 6000000, 4900000, 5200000, 17000000]
data_2.sort()

median_2 = (data_2[(len(data_2)//2)-1] + data_2[len(data_2)//2]) / 2
print(median_2)
# Out:
# 5650000.0

# %% [markdown]
# Sekarang tampilkan hasil perhitunganmu!

# %%
print('\tData 1\t\tData2')
print(f'Mean\t{mean_1:.2f}\t{mean_2:.2f}')
print(f'Median\t{median_1:.2f}\t{median_2:.2f}')
# Out:
# 	Data 1		Data2
# Mean	5514285.71	6950000.00
# Median	5500000.00	5650000.00

# %% [markdown]
# Apa yang terjadi dengan nilai rataan dan median data karyawan gaji sekarang? Menurutmu mengapa hal tersebut terjadi? Coba Interpretasikan hasil pengamatanmu!

# %% [markdown]
# > Nilai ekstrem, dalam konteks ini dapat disebut juga dengan *outlier*, sangat memengaruhi nilai rata-rata. Sementara itu, nilai median tidak berubah drastis. Rata-rata memiliki sensitivitas yang lebih tinggi terhadap nilai ekstrem dibandingkan dengan median. Oleh karena itu, ketika suatu dataset mengandung nilai ekstrem, nilai median menjadi preferensi untuk digunakan sebagai patokan analisis.

# %% [markdown]
# ---

# %% [markdown]
# # **2. Komparasi Simpangan Baku**
#
# Pada bagian ini kalian akan mengamati nilai penyebaran data.
#
# Simpangan baku (standard deviation) adalah ukuran statistik yang digunakan untuk mengukur sebaran atau dispersi data dalam sebuah sampel atau populasi. Simpangan baku menggambarkan sejauh mana nilai-nilai data tersebar di sekitar rata-rata (mean) dalam suatu distribusi.
#
# \begin{equation}
# \sigma = \sqrt{\frac{\sum{(x - \mu)^2}}{N}}
# \end{equation}
#
# * σ adalah simpangan baku.
# * 𝒙 adalah nilai data dalam sampel atau populasi.
# * μ adalah rata-rata (mean) dari data.
# * ∑ adalah simbol sigma yang menunjukkan penjumlahan.
# * 𝑵 adalah jumlah total nilai dalam sampel atau populasi.
# <br><br>

# %% [markdown]
# ## 📖 **Soal**
#
# Karena ketidakpastian situasi global, memaksa DQTech untuk melakukan efisiensi. Dari beberapa produk yang DQTech jual, DQTech harus mengeliminasi 1 produk. Data penjualan pada periode waktu tertentu disajikan pada list berikut :
#
# Penjualan produk A (secara kuantitas tiap bulannya)
# ```
# penjualan_produk_A = [55, 49, 48, 50, 52, 47, 51, 50, 53, 48, 50, 49, 51, 46, 50]
# ```
#
# Penjualan produk B (secara kuantitas tiap bulannya)
# ```
# penjualan_produk_B = [80, 20, 45, 65, 30, 90, 10, 110, 60, 55, 75, 35, 48, 50, 25]
# ```
#
# Coba hitung simpangan baku dari `penjualan_produk_A` dan `penjualan_produk_B` dan bantu DQTech menentukan mana produk yang sebaiknya dipertahankan? Mengapa?

# %%
penjualan_produk_A = [55, 49, 48, 50, 52, 47, 51, 50, 53, 48, 50, 49, 51, 46, 50]
penjualan_produk_B = [80, 20, 45, 65, 30, 90, 10, 110, 60, 55, 75, 35, 48, 50, 25]

# Menghitung rata-rata penjualan
avg_produk_A = sum(penjualan_produk_A) / len(penjualan_produk_A)
avg_produk_B = sum(penjualan_produk_B) / len(penjualan_produk_B)

# Menampilkan rata-rata penjualan
print(f'Rata-rata penjualan produk A: {avg_produk_A:.2f}')
print(f'Rata-rata penjualan produk B: {avg_produk_B:.2f}')

# Membuat fungsi untuk menghitung simpangan baku
def calculate_std_dev(data):
  n = len(data)
  avg = sum(data) / n
  var = sum((x - avg) ** 2 for x in data) / n
  std_dev = var ** 0.5
  return std_dev

# Menghitung simpangan baku
std_dev_A = calculate_std_dev(penjualan_produk_A)
std_dev_B = calculate_std_dev(penjualan_produk_B)

# Menampilkan simpangan baku
print(f'\nSimpangan baku produk A: {std_dev_A:.2f}')
print(f'Simpangan baku produk B: {std_dev_B:.2f}')
# Out:
# Rata-rata penjualan produk A: 49.93
# Rata-rata penjualan produk B: 53.20
#
# Simpangan baku produk A: 2.24
# Simpangan baku produk B: 26.71

# %%
import matplotlib.pyplot as plt

# Mengatur bulan sebagai x-axis
month = list(range(1, len(penjualan_produk_A) + 1))

# Membuat grafik visualisasi penjualan per bulan
plt.figure(figsize=(12, 6))
plt.plot(month, penjualan_produk_A, label='Produk A', marker='o', linestyle='-')
plt.plot(month, penjualan_produk_B, label='Produk B', marker='s', linestyle='--')

# Menambahkan nilai rata-rata ke dalam grafik
plt.axhline(y=avg_produk_A, color='blue', linestyle=':', label=f'Rata-rata A: {avg_produk_A:.2f}')
plt.axhline(y=avg_produk_B, color='orange', linestyle=':', label=f'Rata-rata B: {avg_produk_B:.2f}')

# Mengatur elemen grafik
plt.title('Penjualan Produk A dan B per Bulan', fontsize=14)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Jumlah Penjualan', fontsize=12)
plt.xticks(month)
plt.legend()
plt.grid(alpha=0.5)
plt.tight_layout()

# Menampilkan grafik
plt.show()

# %% [markdown]
# > Produk yang sebaiknya dipertahankan adalah produk A dengan simpangan baku yang lebih kecil, menggambarkan nilai penjualan per bulan yang dekat (tidak berbeda jauh) dengan rata-rata penjualan keseluruhan. Artinya, penjualan produk A lebih stabil. Hal ini dapat diinterpretasikan sebagai produk A memiliki *customer base* yang lebih kuat daripada produk B dan akan membantu DQTech dalam proses efisiensinya, salah satunya dalam pengelolaan stok barang.
